# %% [markdown]
# ### Treatment

# %%
import pandas as pd
import numpy as np

treatment = pd.read_csv('treatment.csv')
print(treatment)
# Out:
#       No                                     Treatment  \
# 0      1                                  Consultation
# 1      2              Consultation and TP presentation
# 2      3                            Treatment Planning
# 3      4                        Quick clean - scalling
# 4      5                Routine Clean - dental checkup
# ..   ...                                           ...
# 117  118                 Provisional crown – per tooth
# 118  119  Repair of crown, bridge or splint - indirect
# 119  120    Repair of crown, bridge or splint – direct
# 120  121                                       Monit 1
# 121  122                                  Post-Aligner
#
#                        item number list
# 0                                   015
# 1                               015/018
# 2                   037.072.073.221.011
# 3                                   114
# 4                       013.114.121.141
# ..                                  ...
# ...

# %%
import pandas as pd
import re

# Function to clean the data for each entry in the DataFrame
def clean_data(input_string):
    # Handle empty or missing values
    if pd.isna(input_string):
        return []
    
    # Remove spaces
    input_string = input_string.replace(' ', '')

    # Handle groups like (825/825/071)x3 where each number in the group should be repeated N times
    def handle_group_multiplier(match):
        numbers_in_group = match.group(1)
        repeat_count = int(match.group(2))
        # Split the numbers and repeat them N times
        numbers = re.split(r'[^0-9]+', numbers_in_group)
        return ', '.join(numbers * repeat_count)

    # Replace group multiplier patterns like (825/825/071)x3
    input_string = re.sub(r'\(([^()]+)\)x(\d+)', handle_group_multiplier, input_string)
    
    # Handle individual 'x' multiplier cases inside groups (e.g., '862x6' becomes '862, 862, 862, 862, 862, 862')
    def handle_single_multiplier(match):
        number, count = match.groups()
        return ', '.join([number] * int(count))
    
    # Replace single 'x' patterns (e.g., '862x6')
    input_string = re.sub(r'(\d+)x(\d+)', handle_single_multiplier, input_string)

    # Split numbers by non-digit characters and return a list of strings (to preserve leading zeros)
    numbers = re.split(r'[^0-9]+', input_string)
    return [num.zfill(3) for num in numbers if num]  # Ensure leading zeros are preserved

# # Load the CSV file into a pandas DataFrame
# df = pd.read_csv('your_file.csv')  # Replace 'your_file.csv' with your actual file path

# # Apply the clean_data function to the 'item number list' column
# df['cleaned_item_numbers'] = df['item number list'].apply(clean_data)

# # Output the updated DataFrame
# print(df[['item number list', 'cleaned_item_numbers']])

# %%
treatment['cleaned_item_numbers'] = treatment['item number list'].apply(clean_data)
treatment.to_csv('cleaned_treatment.csv', index=False)

# %%
treatment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   No                    122 non-null    int64
#  1   Treatment             122 non-null    object
#  2   item number list      122 non-null    object
#  3   cleaned_item_numbers  122 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.9+ KB

# %% [markdown]
# ### Item Code

# %%
item_code = pd.read_csv('item_code.csv')
item_code
# Out:
#        No AU Time (Min)  Offer Gaia Price AUD  Cost Material AUD  \
# 0      11       0:30:00                  49.0                 15
# 1      12       0:15:00                  33.0                 10
# 2      13       0:15:00                  30.0                  9
# 3      14       0:15:00                  34.0                 10
# 4      15       0:30:00                  83.0                 25
# ..    ...           ...                   ...                ...
# 337   986       0:30:00                  71.0                 21
# 338   987       0:30:00                  67.0                 20
# 339   990       0:45:00                 134.0                 40
# 340   999       0:30:00                   0.0                  0
# 341  1Dsy       0:30:00                  96.0                 29
#
#      Offer Gaia Price IDR  Cost Material IDR
# 0                  160000              48000
# 1                  140000              42000
# 2                  110000              33000
# ...

# %%
# make column 'No' to be string and for the leading zeros to be preserved only for values contain only 2 digits
item_code['No'] = item_code['No'].apply(lambda x: str(x).zfill(3) if len(str(x)) == 2 else str(x))
item_code.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   No                    342 non-null    object
#  1   AU Time (Min)         342 non-null    object
#  2   Offer Gaia Price AUD  342 non-null    float64
#  3   Cost Material AUD     342 non-null    int64
#  4   Offer Gaia Price IDR  342 non-null    int64
#  5   Cost Material IDR     342 non-null    int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 16.2+ KB

# %%
def convert_to_minutes(time_string):
    # Split the time string into hours, minutes, and seconds
    try:
        hours, minutes, seconds = map(int, time_string.split(':'))
        # Calculate total minutes: hours * 60 + minutes + seconds / 60
        total_minutes = hours * 60 + minutes + seconds / 60
        return total_minutes
    except ValueError:
        return None  # Return None for invalid or NaN inputs

# %%
# convert column AU Time (Min) to float
item_code['AU Time (Min)'] = item_code['AU Time (Min)'].apply(convert_to_minutes)

# %%
item_code
# Out:
#        No  AU Time (Min)  Offer Gaia Price AUD  Cost Material AUD  \
# 0     011           30.0                  49.0                 15
# 1     012           15.0                  33.0                 10
# 2     013           15.0                  30.0                  9
# 3     014           15.0                  34.0                 10
# 4     015           30.0                  83.0                 25
# ..    ...            ...                   ...                ...
# 337   986           30.0                  71.0                 21
# 338   987           30.0                  67.0                 20
# 339   990           45.0                 134.0                 40
# 340   999           30.0                   0.0                  0
# 341  1Dsy           30.0                  96.0                 29
#
#      Offer Gaia Price IDR  Cost Material IDR
# 0                  160000              48000
# 1                  140000              42000
# ...

# %%
item_code.columns = ['item_number', 'duration', 'price AUD', 'cost_material AUD', 'price IDR', 'cost_material IDR']

# %%
item_code.to_csv('cleaned_item_code.csv', index=False)

# %%
print(item_code)
# Out:
#     item_number  duration  price AUD  cost_material AUD  price IDR  \
# 0           011      30.0       49.0                 15     160000
# 1           012      15.0       33.0                 10     140000
# 2           013      15.0       30.0                  9     110000
# 3           014      15.0       34.0                 10     100000
# 4           015      30.0       83.0                 25     260000
# ..          ...       ...        ...                ...        ...
# 337         986      30.0       71.0                 21     256500
# 338         987      30.0       67.0                 20      73500
# 339         990      45.0      134.0                 40      73500
# 340         999      30.0        0.0                  0          0
# 341        1Dsy      30.0       96.0                 29     283000
#
#      cost_material IDR
# 0                48000
# 1                42000
# 2                33000
# 3                30000
# 4                78000
# ...

# %% [markdown]
# #### Get Price

# %%
import pandas as pd
import ast  # To safely evaluate the string representation of lists in 'cleaned_item_numbers'

# Load the CSV files
item_code_df = pd.read_csv('cleaned_item_code.csv')
treatment_df = pd.read_csv('cleaned_treatment.csv')

# Create dictionaries from item_code_df for fast look-up of prices and costs in both AUD and IDR
item_price_aud_dict = dict(zip(item_code_df['item_number'].astype(str), item_code_df['price AUD']))
item_price_idr_dict = dict(zip(item_code_df['item_number'].astype(str), item_code_df['price IDR']))
item_cost_material_aud_dict = dict(zip(item_code_df['item_number'].astype(str), item_code_df['cost_material AUD']))
item_cost_material_idr_dict = dict(zip(item_code_df['item_number'].astype(str), item_code_df['cost_material IDR']))
item_duration_dict = dict(zip(item_code_df['item_number'].astype(str), item_code_df['duration']))

# Function to calculate total price in AUD and IDR for each treatment based on cleaned_item_numbers
def calculate_total_price(cleaned_item_numbers, currency='AUD'):
    total_price = 0
    # Convert string representation of the list to an actual list
    item_codes = ast.literal_eval(cleaned_item_numbers)
    # Choose the correct price dictionary based on currency
    price_dict = item_price_aud_dict if currency == 'AUD' else item_price_idr_dict
    # Accumulate the prices from the appropriate dictionary
    for item_code in item_codes:
        total_price += price_dict.get(item_code, 0)  # Default to 0 if item_code is not found
    return total_price

# Function to calculate total cost material in AUD and IDR
def calculate_total_cost(cleaned_item_numbers, currency='AUD'):
    total_cost = 0
    # Convert string representation of the list to an actual list
    item_codes = ast.literal_eval(cleaned_item_numbers)
    # Choose the correct cost material dictionary based on currency
    cost_dict = item_cost_material_aud_dict if currency == 'AUD' else item_cost_material_idr_dict
    # Accumulate the costs from the appropriate dictionary
    for item_code in item_codes:
        total_cost += cost_dict.get(item_code, 0)  # Default to 0 if item_code is not found
    return total_cost

# Function to calculate total duration for each treatment
def calculate_total_duration(cleaned_item_numbers):
    total_duration = 0
    # Convert string representation of the list to an actual list
    item_codes = ast.literal_eval(cleaned_item_numbers)
    # Accumulate the durations from item_code_df
    for item_code in item_codes:
        total_duration += item_duration_dict.get(item_code, 0)  # Default to 0 if item_code is not found
    return total_duration

# Apply the functions to each row in the treatment_df for both AUD and IDR
treatment_df['total_price_AUD'] = treatment_df['cleaned_item_numbers'].apply(calculate_total_price, currency='AUD')
treatment_df['total_price_IDR'] = treatment_df['cleaned_item_numbers'].apply(calculate_total_price, currency='IDR')
treatment_df['total_cost_AUD'] = treatment_df['cleaned_item_numbers'].apply(calculate_total_cost, currency='AUD')
treatment_df['total_cost_IDR'] = treatment_df['cleaned_item_numbers'].apply(calculate_total_cost, currency='IDR')
treatment_df['total_duration'] = treatment_df['cleaned_item_numbers'].apply(calculate_total_duration)

# Create a new DataFrame with Treatment and total prices/costs in AUD and IDR
aggregated_df = treatment_df[['Treatment', 'total_price_AUD', 'total_price_IDR', 'total_cost_AUD', 'total_cost_IDR', 'total_duration']]

aggregated_df
# Out:
#                                         Treatment  total_price_AUD  \
# 0                                    Consultation             83.0
# 1                Consultation and TP presentation            100.0
# 2                              Treatment Planning            178.0
# 3                          Quick clean - scalling             83.0
# 4                  Routine Clean - dental checkup            156.0
# ..                                            ...              ...
# 117                 Provisional crown – per tooth            331.0
# 118  Repair of crown, bridge or splint - indirect            205.0
# 119    Repair of crown, bridge or splint – direct            148.0
# 120                                       Monit 1            209.0
# 121                                  Post-Aligner            588.0
#
#      total_price_IDR  total_cost_AUD  total_cost_IDR  total_duration
# 0             260000              25           78000            30.0
# ...

# %%
aggregated_df.to_csv('treatment_with_details.csv', index=False)

# %% [markdown]
# #### Upselling Recommendation

# %%
import pandas as pd
import numpy as np

# %%
upsell = pd.read_csv('upselling_recommendation.csv')
print(upsell)
# Out:
#       No                                     Treatment  \
# 0      1                                  Consultation
# 1      2              Consultation and TP presentation
# 2      3                            Treatment Planning
# 3      4                        Quick clean - scalling
# 4      5                Routine Clean - dental checkup
# ..   ...                                           ...
# 116  117                     2 Bridge treatment  1A,1P
# 117  118                 Provisional crown – per tooth
# 118  119  Repair of crown, bridge or splint - indirect
# 119  120    Repair of crown, bridge or splint – direct
# 120  121                                       Monit 1
#
#                                                 Upsell
# 0                 Comprehensive Oral Health Assessment
# 1        Advanced Treatment Plan with Smile Simulation
# 2              Premium Treatment Strategy Consultation
# 3                    Quick Clean + Fluoride Protection
# ...

# %%
upsell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   No         121 non-null    int64
#  1   Treatment  121 non-null    object
#  2   Upsell     120 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 3.0+ KB

# %%
import pandas as pd
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
import re

# Sample data - replace this with the actual CSV loading
treatment_df = pd.read_csv('upselling_recommendation.csv')

# Function to preprocess and tokenize the text into keywords
def preprocess(text):
    if pd.isna(text):  # Check if the value is NaN or missing
        return set()  # Return an empty set for missing values
    # Ensure the value is a string (in case it's not)
    text = str(text).lower()
    # Remove special characters (e.g., punctuation)
    text = re.sub(r'[^a-z0-9\s]', '', text)
    # Split into words (tokens)
    tokens = text.split()
    # Remove stopwords (common words like "the", "and")
    tokens = [word for word in tokens if word not in ENGLISH_STOP_WORDS]
    # Return the tokens as a set (to handle unique keywords)
    return set(tokens)

# Function to calculate Jaccard similarity between two sets of tokens
def jaccard_similarity(set1, set2):
    intersection = set1.intersection(set2)
    union = set1.union(set2)
    if len(union) == 0:
        return 0
    return len(intersection) / len(union)

# Preprocess the Treatment column
treatment_df['treatment_keywords'] = treatment_df['Treatment'].apply(preprocess)

# Preprocess the Upsell column
treatment_df['upsell_keywords'] = treatment_df['Upsell'].apply(preprocess)

# Function to predict the most similar treatment for each upsell and calculate Jaccard score
def predict_upsell(upsell_keywords, current_treatment):
    best_match = None
    best_similarity = 0
    for index, row in treatment_df.iterrows():
        treatment_keywords = row['treatment_keywords']
        # Skip the current row (to avoid comparing a treatment with itself)
        if row['Treatment'] == current_treatment:
            continue
        similarity = jaccard_similarity(upsell_keywords, treatment_keywords)
        if similarity > best_similarity:
            best_similarity = similarity
            best_match = row['Treatment']
    return best_match, best_similarity

# Apply the prediction function and extract both the predicted treatment and Jaccard score
treatment_df[['Predicted Upsell Treatment', 'Jaccard Score']] = treatment_df.apply(
    lambda row: pd.Series(predict_upsell(row['upsell_keywords'], row['Treatment'])),
    axis=1
)

# Output the updated DataFrame with the predicted upsell treatment and Jaccard score
treatment_df

# Save the new DataFrame to a CSV if needed
# treatment_df.to_csv('predicted_treatments_with_jaccard.csv', index=False)
# Out:
#       No                                     Treatment  \
# 0      1                                  Consultation
# 1      2              Consultation and TP presentation
# 2      3                            Treatment Planning
# 3      4                        Quick clean - scalling
# 4      5                Routine Clean - dental checkup
# ..   ...                                           ...
# 116  117                     2 Bridge treatment  1A,1P
# 117  118                 Provisional crown – per tooth
# 118  119  Repair of crown, bridge or splint - indirect
# 119  120    Repair of crown, bridge or splint – direct
# 120  121                                       Monit 1
#
#                                                 Upsell  \
# 0                 Comprehensive Oral Health Assessment
# 1        Advanced Treatment Plan with Smile Simulation
# 2              Premium Treatment Strategy Consultation
# 3                    Quick Clean + Fluoride Protection
# ...

# %%
treatment_df.to_csv('predicted_upsell_recommendation.csv', index=False)

# %%
treatment_df.head(20)
# Out:
#     No                         Treatment  \
# 0    1                      Consultation
# 1    2  Consultation and TP presentation
# 2    3                Treatment Planning
# 3    4            Quick clean - scalling
# 4    5    Routine Clean - dental checkup
# 5    6                  Advanced Hygiene
# 6    7                       Basic Clean
# 7    8                   Prevention Seal
# 8    9                      Caries Xrays
# 9   10            Minor Fill front teeth
# 10  11             Minor Fill back teeth
# 11  12           Medium Fill Front teeth
# 12  13            Medium Fill Back teeth
# 13  14            Major fill Front Teeth
# 14  15             Major fill Back Teeth
# 15  16             Baby Tooth Extraction
# 16  17                 Minor Extraction
# 17  18                Medium Extraction
# 18  19                  Major Extraction
# 19  20                         Emergency
#
#                                              Upsell  \
# ...

# %% [markdown]
# ### Clarity Data Preprocessing

# %%
import pandas as pd
import numpy as np

clarity_data = pd.read_csv('clarity_data.csv', dtype={'Code': str})
clarity_data
# Out:
#               Code              Category  Description  Demand       Price  \
# 0               11   Diagnostic services          NaN    1548   64.682494
# 1               12   Diagnostic services          NaN    2286   60.530227
# 2               13   Diagnostic services          NaN    1050   51.481676
# 3               14   Diagnostic services          NaN     131   70.080153
# 4               22   Diagnostic services          NaN    8716   48.085593
# ..             ...                   ...          ...     ...         ...
# 160          88522  Restorative services          NaN       1  143.800000
# 161  Dr Invis Cons   Diagnostic services          NaN       1    0.000000
# 162            FIC   Diagnostic services          NaN       2    0.000000
# 163            281          Periodontics          NaN       1  420.000000
# 164            618        Prosthodontics          NaN       1         NaN
#
#      Service Time  Operational Expense  Number of Dentist  Demand per Day  \
# ...

# %%
clarity_data = clarity_data[['Code', 'Demand']]
clarity_data
# Out:
#               Code  Demand
# 0               11    1548
# 1               12    2286
# 2               13    1050
# 3               14     131
# 4               22    8716
# ..             ...     ...
# 160          88522       1
# 161  Dr Invis Cons       1
# 162            FIC       2
# 163            281       1
# 164            618       1
#
# [165 rows x 2 columns]

# %%
# plis make the column 'Code' to be string and for the leading zeros to be preserved only for values contain only 2 digits
clarity_data['Code'] = clarity_data['Code'].apply(lambda x: str(x).zfill(3) if len(str(x)) == 2 else str(x))
clarity_data
# Out:
# C:\Users\Zak\AppData\Local\Temp\ipykernel_16288\3500266292.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clarity_data['Code'] = clarity_data['Code'].apply(lambda x: str(x).zfill(3) if len(str(x)) == 2 else str(x))
#               Code  Demand
# 0              011    1548
# 1              012    2286
# 2              013    1050
# 3              014     131
# 4              022    8716
# ..             ...     ...
# 160          88522       1
# 161  Dr Invis Cons       1
# 162            FIC       2
# 163            281       1
# 164            618       1
#
# [165 rows x 2 columns]

# %%
# for column of code, please do strip only the last 3 characters
# plis make the column 'Code' to be string and for the leading zeros to be preserved only for values contain only 2 digits


clarity_data['Code'] = clarity_data['Code'].str[-3:]
clarity_data
# Out:
# C:\Users\Zak\AppData\Local\Temp\ipykernel_16288\1057984012.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clarity_data['Code'] = clarity_data['Code'].str[-3:]
#     Code  Demand
# 0    011    1548
# 1    012    2286
# 2    013    1050
# 3    014     131
# 4    022    8716
# ..   ...     ...
# 160  522       1
# 161  ons       1
# 162  FIC       2
# 163  281       1
# 164  618       1
#
# [165 rows x 2 columns]

# %%
# for column code please convert to integer, if it is error, just fill with NaN


clarity_data['Code'] = pd.to_numeric(clarity_data['Code'], errors='coerce')


# delete all the rows with NaN values
clarity_data = clarity_data.dropna()
clarity_data
# Out:
# C:\Users\Zak\AppData\Local\Temp\ipykernel_16288\690721655.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clarity_data['Code'] = pd.to_numeric(clarity_data['Code'], errors='coerce')
#       Code  Demand
# 0     11.0    1548
# 1     12.0    2286
# 2     13.0    1050
# 3     14.0     131
# 4     22.0    8716
# ..     ...     ...
# 158  632.0       2
# 159  658.0       1
# 160  522.0       1
# 163  281.0       1
# 164  618.0       1
#
# [153 rows x 2 columns]

# %%
#let's go back convert Code to string and fill with leading zeros
clarity_data['Code'] = clarity_data['Code'].astype(int).astype(str).str.zfill(3)
clarity_data
# Out:
# C:\Users\Zak\AppData\Local\Temp\ipykernel_16288\1565966629.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clarity_data['Code'] = clarity_data['Code'].astype(int).astype(str).str.zfill(3)
#     Code  Demand
# 0    011    1548
# 1    012    2286
# 2    013    1050
# 3    014     131
# 4    022    8716
# ..   ...     ...
# 158  632       2
# 159  658       1
# 160  522       1
# 163  281       1
# 164  618       1
#
# [153 rows x 2 columns]

# %%
# if there are duplicate rows, sum the demand for each code
clarity_data = clarity_data.groupby('Code', as_index=False).agg({'Demand': 'sum'})

# %%
clarity_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Code    127 non-null    object
#  1   Demand  127 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.1+ KB

# %%
clarity_data.to_csv('cleaned_clarity_data.csv', index=False)

# %% [markdown]
# ### Clarity Data Preprocessing 2023 (with dentist information)

# %%
import pandas as pd
import numpy as np

clarity_data = pd.read_csv('clarity_data_2023.csv', dtype={'Code': str})
clarity_data
# Out:
#         Code Provider  Demand
# 0        927     NOTE     118
# 1         11     NOTE      29
# 2       9999     NOTE       2
# 3      D9986     NOTE       7
# 4         11       RE     447
# ..       ...      ...     ...
# 314     9999       WS      59
# 315      Cem       WS      18
# 316    D9986       WS      90
# 317   Insert       WS      12
# 318  Spl Ins       WS       2
#
# [319 rows x 3 columns]

# %%
clarity_data.groupby('Code')['Demand'].sum().reset_index()
# Out:
#         Code  Demand
# 0         11     904
# 1        111       1
# 2        113     103
# 3        114    1659
# 4        115      63
# ..       ...     ...
# 125      FIC       2
# 126   Insert      12
# 127   InvisR      10
# 128   Script      29
# 129  Spl Ins       2
#
# [130 rows x 2 columns]

# %%
clarity_data = pd.read_csv('clarity_data_2023.csv', dtype={'Code': str})
clarity_data['Code'] = clarity_data['Code'].apply(lambda x: str(x).zfill(3) if len(str(x)) == 2 else str(x))
clarity_data['Code'] = clarity_data['Code'].str[-3:]
clarity_data['Code'] = pd.to_numeric(clarity_data['Code'], errors='coerce')
clarity_data = clarity_data.dropna()
clarity_data['Code'] = clarity_data['Code'].astype(int).astype(str).str.zfill(3)
clarity_data = clarity_data.groupby(['Code', 'Provider'], as_index=False).agg({'Demand': 'sum'})
clarity_data.to_csv('cleaned_clarity_data_2023.csv', index=False)
clarity_data

# %%
pd.DataFrame(clarity_data.groupby('Provider')['Demand'].sum().reset_index().sort_values('Demand', ascending=False))
# Out:
#   Provider  Demand
# 4       RE    9183
# 1       CQ    4313
# 5       WS    2696
# 3     NOTE     156
# 0      BEC      61
# 2       DA      56

# %% [markdown]
# ### Clarity's Treatment Sales Estimation

# %%
import pandas as pd
import random

# Load CSV files into DataFrames, ensure 'Code' is read as a string to retain leading zeros
treatment_df = pd.read_csv('cleaned_treatment.csv')
clarity_data_df = pd.read_csv('cleaned_clarity_data.csv', dtype={'Code': str})

# Convert the 'cleaned_item_numbers' column from string representation to actual lists
treatment_df['cleaned_item_numbers'] = treatment_df['cleaned_item_numbers'].apply(eval)
treatment_df
# Out:
#       No                                     Treatment  \
# 0      1                                  Consultation
# 1      2              Consultation and TP presentation
# 2      3                            Treatment Planning
# 3      4                        Quick clean - scalling
# 4      5                Routine Clean - dental checkup
# ..   ...                                           ...
# 117  118                 Provisional crown – per tooth
# 118  119  Repair of crown, bridge or splint - indirect
# 119  120    Repair of crown, bridge or splint – direct
# 120  121                                       Monit 1
# 121  122                                  Post-Aligner
#
#                        item number list            cleaned_item_numbers
# 0                                   015                           [015]
# 1                               015/018                      [015, 018]
# 2                   037.072.073.221.011       [037, 072, 073, 221, 011]
# ...

# %%
import pandas as pd
import random

# Load CSV files into DataFrames, ensure 'Code' is read as a string to retain leading zeros
treatment_df = pd.read_csv('cleaned_treatment.csv')
clarity_data_df = pd.read_csv('cleaned_clarity_data.csv', dtype={'Code': str})
treatment_details_df = pd.read_csv('treatment_with_details.csv')  # Load treatment details with durations

# Convert the 'cleaned_item_numbers' column from string representation to actual lists
treatment_df['cleaned_item_numbers'] = treatment_df['cleaned_item_numbers'].apply(eval)

# Create a dictionary to store treatment demand and a set to track infeasible treatments
treatment_demand = {}
infeasible_treatments = set()  # Store infeasible treatments

# Function to check if the treatment is feasible
def is_feasible(treatment_item_codes, clarity_data_df):
    for item_code in treatment_item_codes:
        item_code_str = str(item_code).zfill(3)  # Ensure item code has leading zeros (3 digits)
        remaining_demand = clarity_data_df.loc[clarity_data_df['Code'] == item_code_str, 'Demand'].sum()
        # Check if the remaining demand is sufficient for the number of times the item code appears in the treatment
        if remaining_demand < treatment_item_codes.count(item_code):
            return False
    return True

# Function to update the demand in cleaned_clarity_data
def update_demand(treatment_item_codes, clarity_data_df):
    for item_code in treatment_item_codes:
        item_code_str = str(item_code).zfill(3)  # Ensure item code has leading zeros (3 digits)
        clarity_data_df.loc[clarity_data_df['Code'] == item_code_str, 'Demand'] -= treatment_item_codes.count(item_code)
        print(f"Updated demand for item code {item_code_str}")

# Main loop to randomly select treatments
infeasibility_counter = 0
max_infeasibility_attempts = 100

while infeasibility_counter < max_infeasibility_attempts:
    # Exclude infeasible treatments from random selection
    available_treatments = treatment_df[~treatment_df['Treatment'].isin(infeasible_treatments)]
    
    # If no more treatments are available, break the loop
    if available_treatments.empty:
        print("No more feasible treatments to select.")
        break
    
    # Randomly select a treatment from the available treatments
    selected_treatment = available_treatments.sample(1).iloc[0]
    treatment_name = selected_treatment['Treatment']
    treatment_item_codes = selected_treatment['cleaned_item_numbers']
    
    # Check if the selected treatment is feasible
    if is_feasible(treatment_item_codes, clarity_data_df):
        # Update demand for item codes in the selected treatment
        update_demand(treatment_item_codes, clarity_data_df)
        
        # Add the treatment to the treatment demand DataFrame or increment its demand
        if treatment_name in treatment_demand:
            treatment_demand[treatment_name] += 1
        else:
            treatment_demand[treatment_name] = 1
        
        # Reset infeasibility counter after a successful draw
        infeasibility_counter = 0
    else:
        # Add the treatment to the set of infeasible treatments
        infeasible_treatments.add(treatment_name)
        # Increment infeasibility counter if the treatment is not feasible
        infeasibility_counter += 1

# Convert treatment demand dictionary to DataFrame
final_treatment_demand_df = pd.DataFrame(list(treatment_demand.items()), columns=['Treatment', 'Demand'])

# Merge with treatment details to add total_duration
final_treatment_demand_df = final_treatment_demand_df.merge(treatment_details_df[['Treatment', 'total_duration']], on='Treatment', how='left')

# Calculate total duration for each treatment (total_duration * demand)
final_treatment_demand_df['total_duration_for_demand'] = final_treatment_demand_df['total_duration'] * final_treatment_demand_df['Demand']
# Out:
# Updated demand for item code 071
# Updated demand for item code 071
# Updated demand for item code 613
# Updated demand for item code 613
# Updated demand for item code 613
# Updated demand for item code 613
# Updated demand for item code 613
# Updated demand for item code 613
# Updated demand for item code 022
# Updated demand for item code 022
# Updated demand for item code 022
# Updated demand for item code 022
# Updated demand for item code 022
# Updated demand for item code 022
# Updated demand for item code 071
# Updated demand for item code 071
# Updated demand for item code 613
# Updated demand for item code 613
# Updated demand for item code 613
# Updated demand for item code 022
# Updated demand for item code 022
# Updated demand for item code 022
# Updated demand for item code 013
# Updated demand for item code 014
# Updated demand for item code 728
# Updated demand for item code 731
# Updated demand for item code 731
# Updated demand for item code 731
# ...

# %%
# Display the final DataFrame of treatment demands with total durations
print("Final Treatment Demand with Total Duration:")
final_treatment_demand_df
# Out:
# Final Treatment Demand with Total Duration:
#                                             Treatment  Demand  total_duration  \
# 0                                             6 Crown       1           470.0
# 1                                             3 Crown       1           245.0
# 2   Metal partial denture treatment of lower parti...       1           340.0
# 3        Repair of crown, bridge or splint - indirect       1            45.0
# 4   Metal partial denture treatment of lower parti...       1           330.0
# 5                                             5 Crown       1           455.0
# 6   Denture Reparation (Adding tooth to partial de...       2            80.0
# 7                      Routine Clean - dental checkup       4            65.0
# 8   Metal partial denture treatment of upper parti...       1           330.0
# 9                             Prevention Seal package       5            75.0
# ...

# %%
# sum all column of total_duration_for_demand
total_duration_for_demand = final_treatment_demand_df['total_duration_for_demand'].sum()
total_duration_for_demand / 60 / 10
# Out:
# 221.425

# %%
# Check and display remaining demand in cleaned_clarity_data.csv
if infeasibility_counter >= max_infeasibility_attempts:
    print(f"\nReached max infeasibility attempts ({max_infeasibility_attempts}).")
    print("Remaining demand in cleaned_clarity_data.csv:")
    remaining_demand_df = clarity_data_df[clarity_data_df['Demand'] > 0]
    
    
remaining_demand_df

# Save to CSV if needed
# final_treatment_demand_df.to_csv('final_treatment_demand_with_duration.csv', index=False)
# remaining_demand_df.to_csv('remaining_demand.csv', index=False)
# Out:
#     Code  Demand
# 0    011    1529
# 1    012    2281
# 2    013    1045
# 3    014     124
# 4    022    8458
# ..   ...     ...
# 146  451       1
# 147  535       2
# 150  522       1
# 151  281       1
# 152  618       1
#
# [138 rows x 2 columns]

# %%
clarity_data_df = pd.read_csv('cleaned_clarity_data.csv', dtype={'Code': str})
clarity_data_df
# Out:
#     Code  Demand
# 0    011    1548
# 1    012    2286
# 2    013    1050
# 3    014     131
# 4    022    8716
# ..   ...     ...
# 148  632       2
# 149  658       1
# 150  522       1
# 151  281       1
# 152  618       1
#
# [153 rows x 2 columns]

# %% [markdown]
# ### Pareto Trial

# %%
import matplotlib.pyplot as plt

def create_pareto_chart(df, basis):
    """Create a Pareto chart based on the given basis (Demand, Revenue Contribution, or Profit Contribution)."""
    if basis not in ['Demand', 'Revenue Contribution', 'Profit Contribution']:
        raise ValueError("Invalid basis. Choose from 'Demand', 'Revenue Contribution', or 'Profit Contribution'.")

    # Sort df by the chosen basis in descending order
    df = df.sort_values(by=basis, ascending=False).reset_index(drop=True)

    # Calculate cumulative percentage for the chosen basis
    total_value = df[basis].sum()
    df['Cumulative %'] = df[basis].cumsum() / total_value * 100

    # Create a combo chart (Pareto chart)
    fig, ax1 = plt.subplots(figsize=(10, 6))

    # Bar chart for the chosen basis
    ax1.bar(df['Code'], df[basis], color='skyblue')
    ax1.set_xlabel('Code')
    ax1.set_ylabel(basis, color='blue')
    ax1.tick_params(axis='y', labelcolor='blue')

    # Create a second y-axis for the cumulative percentage line chart
    ax2 = ax1.twinx()
    ax2.plot(df['Code'], df['Cumulative %'], color='red', marker='o')
    ax2.set_ylabel('Cumulative % of ' + basis, color='red')
    ax2.tick_params(axis='y', labelcolor='red')

    # Set the limits for the right y-axis to always range from 0 to 100%
    ax2.set_ylim(0, 110)

    # Set the title
    plt.title(f'Pareto Chart for {basis}')

    # Display the plot
    plt.tight_layout()
    plt.show()

# %%
df = pd.read_csv('result_df.csv', dtype={'Code': str}).sort_values(by='Profit Contribution', ascending=False).head(20)

create_pareto_chart(df, 'Demand')

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np

def create_pareto_chart(df, basis, top=20):
    """Create a Pareto chart based on the given basis (Demand, Revenue Contribution, or Profit Contribution) using Plotly."""
    if basis not in ['Demand', 'Revenue Contribution', 'Profit Contribution']:
        raise ValueError("Invalid basis. Choose from 'Demand', 'Revenue Contribution', or 'Profit Contribution'.")

    # Sort df by the chosen basis in descending order and select top N
    df = df.sort_values(by=basis, ascending=False).reset_index(drop=True).head(top)

    # Calculate cumulative percentage for the chosen basis
    total_value = df[basis].sum()
    df['Cumulative %'] = df[basis].cumsum() / total_value * 100

    # Create a bar chart for the selected basis
    fig = go.Figure()

    # Add bar chart for basis (e.g., Demand or Revenue Contribution)
    fig.add_trace(
        go.Bar(
            x=df['Code'], 
            y=df[basis], 
            name=basis, 
            marker_color='skyblue', 
            yaxis='y1'
        )
    )

    # Add line chart for cumulative percentage
    fig.add_trace(
        go.Scatter(
            x=df['Code'], 
            y=df['Cumulative %'], 
            name='Cumulative %', 
            mode='lines+markers', 
            marker=dict(color='red'),
            yaxis='y2'
        )
    )

    # Set up the layout for the dual-axis chart
    fig.update_layout(
        title=f'Pareto Chart for {basis}',
        xaxis=dict(title='Code'),
        yaxis=dict(
            title=basis,
            titlefont=dict(color='blue'),
            tickfont=dict(color='blue'),
        ),
        yaxis2=dict(
            title='Cumulative %',
            overlaying='y',
            side='right',
            range=[0, 110],
            titlefont=dict(color='red'),
            tickfont=dict(color='red'),
        ),
        legend=dict(x=0.1, y=1.1),
        width=900,
        height=600,
        bargap=0.2,
    )

    # Show the chart
    fig.show()

# %%
from model import ModelItemCodeAnalysis
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('result_df.csv', dtype={'Code': str}).sort_values(by='Profit Contribution', ascending=False).head(20)

model = ModelItemCodeAnalysis()

model.create_pareto_chart(df, 'Demand')



#

# %% [markdown]
# ### Cleaning Predicted Clarity Treatment

# %%
import pandas as pd
import numpy as np

clarity_data = pd.read_csv('clarity_treatment_1.csv', dtype={'Treatment': str})
clarity_data.to_csv('clarity_treatment_1.csv', index=False)

# %% [markdown]
# ### Treatment Forecast of Cashflow Forecast

# %%
import pandas as pd
import numpy as np

def generate_forecast_treatment_df(treatment_df, cashflow_df, basis="Australia", tolerance=0.1):
    """
    Generates a DataFrame of randomly selected treatments for each period in cashflow_df,
    until the accumulated revenue and expense match the cashflow values within the specified tolerance.
    
    Parameters:
    treatment_df: DataFrame containing treatments with revenue and expense in AUD and IDR.
    cashflow_df: DataFrame containing the cashflow for each period with columns Period, Revenue, Expense.
    basis: "Australia" or "Indonesia", determines whether to use AUD or IDR for revenue and expense.
    tolerance: The tolerance level for revenue and expense matching (as a fraction, e.g., 0.1 for 10%).
    
    Returns:
    forecast_treatment_df: DataFrame with columns Period, Treatment, Revenue, Expense.
    """
    
    # Define which columns to use for revenue and expense based on the basis
    if basis == "Australia":
        revenue_col = 'total_price_AUD'
        expense_col = 'total_cost_AUD'
    elif basis == "Indonesia":
        revenue_col = 'total_price_IDR'
        expense_col = 'total_cost_IDR'
    else:
        raise ValueError("Basis must be 'Australia' or 'Indonesia'")
    
    # Initialize list to store forecast data
    forecast_data = []

    # Loop through each period in cashflow_df
    for i, row in cashflow_df.iterrows():
        period = row['Period']
        target_revenue = row['Revenue']
        target_expense = row['Expense']
        
        # Calculate the tolerance ranges
        revenue_lower_bound = target_revenue * (1 - tolerance)
        revenue_upper_bound = target_revenue * (1 + tolerance)
        expense_lower_bound = target_expense * (1 - tolerance)
        expense_upper_bound = target_expense * (1 + tolerance)
        
        # Initialize accumulators for revenue and expense
        accumulated_revenue = 0
        accumulated_expense = 0
        
        # Select random treatments until revenue and expense are within the tolerance
        while not (revenue_lower_bound <= accumulated_revenue <= revenue_upper_bound and
                   expense_lower_bound <= accumulated_expense <= expense_upper_bound):
            # Randomly select a treatment
            selected_treatment = treatment_df.sample(n=1).iloc[0]
            
            treatment_revenue = selected_treatment[revenue_col]
            treatment_expense = selected_treatment[expense_col]
            
            # Add selected treatment's revenue and expense to the accumulators
            accumulated_revenue += treatment_revenue
            accumulated_expense += treatment_expense
            
            # Append the selected treatment data to the forecast data list
            forecast_data.append({
                'Period': period,
                'Treatment': selected_treatment['Treatment'],
                'Revenue': treatment_revenue,
                'Expense': treatment_expense
            })
    
    # Create a DataFrame from the forecast data
    forecast_treatment_df = pd.DataFrame(forecast_data)
    
    return forecast_treatment_df

# %%
# Example DataFrames (replace with your actual DataFrames)
treatment_df = pd.read_csv('treatment.csv')
cashflow_df = pd.read_csv('cashflow.csv')

# Generate forecasted treatment data
forecast_df = generate_forecast_treatment_df(treatment_df, cashflow_df, basis="Australia", tolerance=0.1)

# View the result
print(forecast_df)
